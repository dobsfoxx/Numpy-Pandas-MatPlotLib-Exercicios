# %%
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/allanspadini/numpy/dados/citrus.csv'

# %%
dado = np.loadtxt(url, delimiter=',', skiprows=1, usecols=np.arange(1,6,1))

# %%
dado.T
# Out:
# array([[  2.96,   3.91,   4.42, ...,  15.59,  15.92,  16.45],
#        [ 86.76,  88.05,  95.17, ..., 256.5 , 260.14, 261.51],
#        [172.  , 166.  , 156.  , ..., 168.  , 142.  , 152.  ],
#        [ 85.  ,  78.  ,  81.  , ...,  82.  ,  72.  ,  74.  ],
#        [  2.  ,   3.  ,   2.  , ...,  20.  ,  11.  ,   2.  ]])

# %%
dado.shape
# Out:
# (10000, 5)

# %%
diametro  = dado[:,0]
peso = dado[:,1]

# %%
diametro_laranja = diametro[0:4999]
diametro_toranja = diametro[5000:]

# %%
peso_laranja = peso[0:4999]
peso_toranja = peso[5000:]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(diametro_laranja, peso_laranja)

# %%
plt.plot(diametro_toranja, peso_toranja)

# %%
Y = peso_laranja
X = diametro_laranja
n = np.size(X)

# %%
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2) - (np.sum(X))**2)
b = np.mean(Y) - a*np.mean(X)

# %%
plt.plot(diametro_laranja, peso_laranja, '*r')
plt.plot(X,Y)

# %%
Y = peso_toranja
X = diametro_toranja
n = np.size(X)

# %%
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2) - (np.sum(X))**2)
b = np.mean(Y) - a*np.mean(X)

# %%
plt.plot(diametro_toranja, peso_toranja, '*r')
plt.plot(X,Y)

# %%
coef_angulares = np.random.uniform(low=1, high=10, size=10)

# %%
normas = np.array([])
for i in range(10):
  normas = np.append(normas, np.linalg.norm(Y-(coef_angulares[i]*X+17)))

# %%
normas
# Out:
# array([ 5181.72913694, 11607.85807067,  6180.70022859, 11110.3293773 ,
#        10705.16422862,  8764.90005672,  6845.30687312,  5792.28498837,
#         5523.62795142,  4958.00976805])
