# %% [markdown]
# <a href="https://colab.research.google.com/github/dobsfoxx/Numpy-Pandas-MatPlotLib-Exercicios/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(vendas_2022)
df.index = lojas
df
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
import matplotlib.pyplot as plt

# %%
fig , axs = plt.subplots(2,2, figsize=(15,10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Vendas mensais das lojas A, B, C e D em 2022')

axs[0,0].plot(df.loc['A'])
axs[0,0].set_title('Vendas de A')

axs[0,1].plot(df.loc['B'])
axs[0,1].set_title('Vendas de B')

axs[1,0].plot(df.loc['C'])
axs[1,0].set_title('Vendas de C')

axs[1,1].plot(df.loc['D'])
axs[1,1].set_title('Vendas de D')

ymin = 0
ymax = 450

for ax in axs.ravel():
    ax.set_ylim(ymin, ymax)
    ax.set_xlabel('Mês')
    ax.set_ylabel('Vendas')
    ax.grid(True)

plt.show()
